# %%
word = "Python is very good"
length = len(word)
print("Length of the word:", length)
# Out:
# Length of the word: 19

# %%
# Swapping 
a, b = 5, 10
print(a, b) 
a, b = b, a
print(a, b)
# Out:
# 5 10
# 10 5

# %%
x = 10
del x
print(x) 
y = 'Hello, World!'
del y
print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 x = 10
#       2 del x
# ----> 3 print(x)
#       4 y = 'Hello, World!'
#       5 del y
#       6 print(y)
#
# NameError: name 'x' is not defined

# %%
x, y, z = 1, 2.5, "Python"
print(x, y, z)
# Out:
# 1 2.5 Python

# %%
print("Kal Roza haay, World!")
# Out:
# Kal Roza haay, World!
