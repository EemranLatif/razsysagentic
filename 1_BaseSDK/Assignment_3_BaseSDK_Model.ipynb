# %% [markdown]
# <h1>RAZ Systems — Assignment 3</h1>
#
# ## Topic: Multi-Model Comparison with an AI Judge
#
# **Instructions:** In Practical 3 you saw how to send the same question to multiple models and rank the answers using a judge model. Now you'll build the same pipeline from scratch — with a twist. Fill in every `# YOUR CODE HERE` section.
#
# ---

# %% [markdown]
# ### Task 1 — Imports and setup
#
# Import everything you need: `os`, `json`, `load_dotenv`, `OpenAI`, and `Markdown`/`display` from IPython. Load your environment and verify at least your `OPENAI_API_KEY` and `GOOGLE_API_KEY`.

# %%
# YOUR CODE HERE — all imports

# YOUR CODE HERE — load_dotenv

# YOUR CODE HERE — check and print key prefixes for OPENAI and GOOGLE

# %% [markdown]
# ### Task 2 — Generate a topic question using GPT
#
# Use `gpt-4.1-nano` to generate **a single, open-ended question** about the ethics of Agentic AI in the workplace. The model should answer with only the question — no preamble or explanation.
#
# Store the question in a variable called `question` and print it.

# %%
openai = OpenAI()

# YOUR CODE HERE — build the request prompt
request = 
messages = [{"role": "user", "content": request}]

# YOUR CODE HERE — call gpt-4.1-nano and store result in `question`
question = 
print(question)

# %% [markdown]
# ### Task 3 — Set up tracking lists and the competitor messages
#
# Create:
# - An empty list called `competitors` — this will store the model names in order
# - An empty list called `answers` — this will store each model's response text
# - A `messages` list containing the generated `question` as a user message

# %%
# YOUR CODE HERE
competitors = 
answers = 
messages =

# %% [markdown]
# ### Task 4 — Get an answer from GPT-4.1-nano
#
# Call the OpenAI API with `model="gpt-4.1-nano"`. Append `"gpt-4.1-nano"` to `competitors` and the response text to `answers`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task 5 — Get an answer from Gemini via the OpenAI-compatible endpoint
#
# Many providers offer an OpenAI-compatible API. Google Gemini is one of them. Create a **new** `OpenAI` client pointed at Google's base URL, call `gemini-2.0-flash`, and append the model name and answer to your tracking lists.
#
# ```python
# # Google's OpenAI-compatible base URL
# base_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
# ```

# %%
import os

# YOUR CODE HERE — create a Google-compatible client
google_client = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"),
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# YOUR CODE HERE — call gemini-2.0-flash and store results

# %% [markdown]
# ### Task 6 — Print all answers for review
#
# Loop through `competitors` and `answers` together using `zip()`. For each one, print a header with the model name and then display the answer as Markdown.

# %%
from IPython.display import Markdown, display

# YOUR CODE HERE

# %% [markdown]
# ### Task 7 — Build the judge prompt
#
# Build a string called `judge` that:
# 1. States the original question
# 2. Shows each model's answer, labelled with its number (1, 2, ...)
# 3. Ends with an instruction telling the judge model to respond **only** with a JSON object in this format: `{"results": ["1", "2"]}` ranked best to worst — no markdown, no explanation
#
# Print `judge` to double-check it looks right before sending it.

# %%
# YOUR CODE HERE
judge = f"Your task is to rank the following AI responses to this question:\n\n"
judge += f"Question: {question}\n\n"

# YOUR CODE HERE — add each answer with its number

# YOUR CODE HERE — add the JSON instruction at the end

print(judge)

# %% [markdown]
# ### Task 8 — Run the judge and parse the results
#
# Send `judge` to `gpt-4.1-mini` as a user message. Parse the JSON response with `json.loads()` and print the ranked model names in order.

# %%
import json

# YOUR CODE HERE — build judge_messages and call gpt-4.1-mini
judge_messages = 

# YOUR CODE HERE — call the API
results_raw = 

# YOUR CODE HERE — parse JSON and print ranked results
results_dict = json.loads(results_raw)
ranks = results_dict["results"]

print("\n🏆 Final Rankings:")
for index, result in enumerate(ranks):
    # YOUR CODE HERE — look up the competitor name by index and print the rank

# %% [markdown]
# ### Reflection question (answer in this cell)
#
# **Why is it useful to use an AI model as a judge rather than just reading the answers yourself?**
#
# *Your answer here...*
#
# ---
# ## ✅ Solution — scroll down only after attempting!
#
# ---

# %%
# SOLUTION — Task 1
import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

load_dotenv(override=True)

openai_api_key = os.getenv('OPENAI_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')

print(f"OpenAI: {openai_api_key[:8]}" if openai_api_key else "OpenAI key not set")
print(f"Google: {google_api_key[:4]}" if google_api_key else "Google key not set")
# Out:
# OpenAI: sk-proj-
# Google: AIza

# %%
# SOLUTION — Task 2
openai = OpenAI()

request = "Come up with a single, open-ended, thought-provoking question about the ethics of Agentic AI in the workplace. Answer only with the question — no preamble, no explanation."
messages = [{"role": "user", "content": request}]

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)
question = response.choices[0].message.content
print(question)
# Out:
# How should we balance the pursuit of efficiency and innovation through agentic AI in the workplace with our obligations to ensure fairness, autonomy, and dignity for human workers?

# %%
# SOLUTION — Task 3
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %%
# SOLUTION — Task 4
response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)
competitors.append("gpt-4.1-nano")
answers.append(response.choices[0].message.content)

# %%
# SOLUTION — Task 5
google_client = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"),
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

response = google_client.chat.completions.create(
    model="gemini-2.0-flash",
    messages=messages
)
competitors.append("gemini-2.0-flash")
answers.append(response.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[5], line 7
#       3     api_key=os.getenv("GOOGLE_API_KEY"),
#       4     base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
#       5 )
#       6
# ----> 7 response = google_client.chat.completions.create(
#       8     model="gemini-2.0-flash",
#       9     messages=messages
#      10 )
#
# File d:\git\agentic\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File d:\git\agentic\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1215, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1168 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1169 def create(
#    1170     self,
#    (...)   1212     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1213 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1214     validate_response_format(response_format)
# -> 1215     return self._post(
#    1216         "/chat/completions",
#    1217         body=maybe_transform(
#    1218             {
#    1219                 "messages": messages,
#    1220                 "model": model,
#    1221                 "audio": audio,
#    1222                 "frequency_penalty": frequency_penalty,
#    1223                 "function_call": function_call,
#    1224                 "functions": functions,
#    1225                 "logit_bias": logit_bias,
#    1226                 "logprobs": logprobs,
#    1227                 "max_completion_tokens": max_completion_tokens,
#    1228                 "max_tokens": max_tokens,
#    1229                 "metadata": metadata,
#    1230                 "modalities": modalities,
#    1231                 "n": n,
#    1232                 "parallel_tool_calls": parallel_tool_calls,
#    1233                 "prediction": prediction,
#    1234                 "presence_penalty": presence_penalty,
#    1235                 "prompt_cache_key": prompt_cache_key,
#    1236                 "prompt_cache_retention": prompt_cache_retention,
#    1237                 "reasoning_effort": reasoning_effort,
#    1238                 "response_format": response_format,
#    1239                 "safety_identifier": safety_identifier,
#    1240                 "seed": seed,
#    1241                 "service_tier": service_tier,
#    1242                 "stop": stop,
#    1243                 "store": store,
#    1244                 "stream": stream,
#    1245                 "stream_options": stream_options,
#    1246                 "temperature": temperature,
#    1247                 "tool_choice": tool_choice,
#    1248                 "tools": tools,
#    1249                 "top_logprobs": top_logprobs,
#    1250                 "top_p": top_p,
#    1251                 "user": user,
#    1252                 "verbosity": verbosity,
#    1253                 "web_search_options": web_search_options,
#    1254             },
#    1255             completion_create_params.CompletionCreateParamsStreaming
#    1256             if stream
#    1257             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1258         ),
#    1259         options=make_request_options(
#    1260             extra_headers=extra_headers,
#    1261             extra_query=extra_query,
#    1262             extra_body=extra_body,
#    1263             timeout=timeout,
#    1264             security={"bearer_auth": True},
#    1265         ),
#    1266         cast_to=ChatCompletion,
#    1267         stream=stream or False,
#    1268         stream_cls=Stream[ChatCompletionChunk],
#    1269     )
#
# File d:\git\agentic\.venv\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\git\agentic\.venv\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-2.0-flash\nPlease retry in 19.319850375s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_input_token_count', 'quotaId': 'GenerateContentInputTokensPerModelPerMinute-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash'}}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '19s'}]}}]

# %%
# SOLUTION — Task 6
for model, answer in zip(competitors, answers):
    display(Markdown(f"### Response from: `{model}`"))
    display(Markdown(answer))
    print("---")
# Out:
# ### Response from: `gpt-4.1-nano`
# Balancing the pursuit of efficiency and innovation through agentic AI with commitments to fairness, autonomy, and dignity for human workers is a complex but crucial challenge. Achieving this balance requires a multifaceted approach that integrates ethical principles, stakeholder engagement, and responsible design. Here are key strategies to consider:
#
# 1. **Embed Ethical Values in AI Design and Deployment**
#    - Incorporate fairness, transparency, and respect for human dignity into AI development processes.
#    - Prioritize human-centered design principles that enhance, rather than diminish, human roles and contributions.
#    - Use ethical review boards or oversight committees to evaluate AI deployment plans.
#
# 2. **Ensure Transparency and Explainability**
#    - Develop AI systems whose decision-making processes can be understood by human workers.
#    - Provide clear explanations about how AI influences tasks, decisions, and workflows to foster trust and autonomy.
#
# 3. **Maintain Human Oversight and Control**
#    - Design agentic AI to augment human decision-making rather than replace it entirely.
#    - Allow human workers to intervene, override, or veto AI recommendations or actions when necessary.
#
# 4. **Promote Fairness and Non-Discrimination**
#    - Regularly audit AI systems for biases or unintended disparate impacts on different groups of workers.
#    - Implement fairness metrics and corrective measures to ensure equitable treatment.
#
# 5. **Protect Worker Autonomy and Dignity**
#    - Involve workers in decision-making about AI integration, respecting their insights and preferences.
#    - Avoid overly prescriptive or exploitable AI policies; instead, foster a participatory approach that values human judgment.
#
# 6. **Invest in Training and Skill Development**
#    - Provide ongoing education to help workers adapt to new AI-enabled workflows.
#    - Empower workers with skills that enhance their autonomy and capacity to work alongside AI.
#
# 7. **Establish Clear Ethical Guidelines and Regulations**
#    - Develop organizational policies aligned with broader societal standards for fair labor practices and AI ethics.
#    - Ensure compliance with legal frameworks protecting workers’ rights and dignity.
#
# 8. **Foster a Culture of Ethical AI Use**
#    - Encourage open dialogue about the societal and individual impacts of AI adoption.
#    - Promote leadership commitment to balancing innovation with social responsibility.
#
# **In summary**, pursuing efficiency and innovation with agentic AI should not come at the expense of human workers’ fairness, autonomy, or dignity. Instead, organizations should adopt an ethical, inclusive, and transparent approach that leverages AI to enhance human worksites while respecting fundamental human values.
# ---

# %%
# SOLUTION — Task 7
judge = f"Your task is to rank the following AI responses to this question:\n\n"
judge += f"Question: {question}\n\n"

for i, (model, answer) in enumerate(zip(competitors, answers), start=1):
    judge += f"Response {i} (from {model}):\n{answer}\n\n"

judge += (
    "Rank the responses from best to worst based on depth, clarity, and insight. "
    'Respond ONLY with a JSON object in this exact format: {"results": ["1", "2"]} '
    "where the numbers are the response numbers in ranked order. "
    "Do not include markdown formatting or any explanation."
)

print(judge)
# Out:
# Your task is to rank the following AI responses to this question:
#
# Question: How should we balance the pursuit of efficiency and innovation through agentic AI in the workplace with our obligations to ensure fairness, autonomy, and dignity for human workers?
#
# Response 1 (from gpt-4.1-nano):
# Balancing the pursuit of efficiency and innovation through agentic AI with commitments to fairness, autonomy, and dignity for human workers is a complex but crucial challenge. Achieving this balance requires a multifaceted approach that integrates ethical principles, stakeholder engagement, and responsible design. Here are key strategies to consider:
#
# 1. **Embed Ethical Values in AI Design and Deployment**
#    - Incorporate fairness, transparency, and respect for human dignity into AI development processes.
#    - Prioritize human-centered design principles that enhance, rather than diminish, human roles and contributions.
#    - Use ethical review boards or oversight committees to evaluate AI deployment plans.
#
# 2. **Ensure Transparency and Explainability**
#    - Develop AI systems whose decision-making processes can be understood by human workers.
#    - Provide clear explanations about how AI influences tasks, decisions, and workflows to foster trust and autonomy.
#
# 3. **Maintain Human Oversight and Control**
#    - Design agentic AI to augment human decision-making rather than replace it entirely.
#    - Allow human workers to intervene, override, or veto AI recommendations or actions when necessary.
#
# 4. **Promote Fairness and Non-Discrimination**
#    - Regularly audit AI systems for biases or unintended disparate impacts on different groups of workers.
#    - Implement fairness metrics and corrective measures to ensure equitable treatment.
#
# 5. **Protect Worker Autonomy and Dignity**
#    - Involve workers in decision-making about AI integration, respecting their insights and preferences.
#    - Avoid overly prescriptive or exploitable AI policies; instead, foster a participatory approach that values human judgment.
#
# 6. **Invest in Training and Skill Development**
#    - Provide ongoing education to help workers adapt to new AI-enabled workflows.
#    - Empower workers with skills that enhance their autonomy and capacity to work alongside AI.
#
# 7. **Establish Clear Ethical Guidelines and Regulations**
#    - Develop organizational policies aligned with broader societal standards for fair labor practices and AI ethics.
#    - Ensure compliance with legal frameworks protecting workers’ rights and dignity.
#
# 8. **Foster a Culture of Ethical AI Use**
#    - Encourage open dialogue about the societal and individual impacts of AI adoption.
#    - Promote leadership commitment to balancing innovation with social responsibility.
#
# **In summary**, pursuing efficiency and innovation with agentic AI should not come at the expense of human workers’ fairness, autonomy, or dignity. Instead, organizations should adopt an ethical, inclusive, and transparent approach that leverages AI to enhance human worksites while respecting fundamental human values.
#
# Rank the responses from best to worst based on depth, clarity, and insight. Respond ONLY with a JSON object in this exact format: {"results": ["1", "2"]} where the numbers are the response numbers in ranked order. Do not include markdown formatting or any explanation.

# %%
# SOLUTION — Task 8
judge_messages = [{"role": "user", "content": judge}]

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=judge_messages
)
results_raw = response.choices[0].message.content

results_dict = json.loads(results_raw)
ranks = results_dict["results"]

print("\n🏆 Final Rankings:")
for index, result in enumerate(ranks):
    competitor = competitors[int(result) - 1]
    print(f"Rank {index + 1}: {competitor}")

# Reflection answer:
# A human reading 2-3 long answers takes time and can be inconsistent.
# An LLM judge can evaluate all answers against the same criteria in seconds,
# at scale — useful when you're running this pipeline across hundreds of queries.
# Out:
# 🏆 Final Rankings:
# Rank 1: gpt-4.1-nano
