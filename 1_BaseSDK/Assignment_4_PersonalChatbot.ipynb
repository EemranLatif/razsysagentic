# %% [markdown]
# <h1>RAZ Systems — Assignment 4</h1>
#
# ## Topic: Your Personal AI Career Assistant
#
# **Based on Practical 4.** You will read your own LinkedIn PDF, load a personal summary you write yourself, build a system prompt, and launch a Gradio chatbot that represents **you** to the world.
#
# ---
#
# ### 📂 Before you start — prepare two files in your project folder:
#
# 1. **`your_linkedin.pdf`** — export your LinkedIn profile as a PDF
#    *(On LinkedIn: click Me → More → Save to PDF)*
#
# 2. **`your_summary.txt`** — a short paragraph you write yourself describing your background, skills, and what you are looking for
#
# ---

# %% [markdown]
# ### Task 1 — Imports and setup
#
# Import everything needed in one cell: `load_dotenv`, `OpenAI`, `PdfReader` from `pypdf`, and `gradio as gr`. Load your environment and create the OpenAI client.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task 2 — Read your LinkedIn PDF
#
# Use `PdfReader` to open `your_linkedin.pdf`. Loop through every page, extract the text, and concatenate it all into a single string called `linkedin`. Print it to verify it loaded correctly.

# %%
reader = PdfReader("your_linkedin.pdf")
linkedin = ""

# YOUR CODE HERE — loop through pages and build the linkedin string


print(linkedin)

# %% [markdown]
# ### Task 3 — Load your personal summary
#
# Open `your_summary.txt` with Python's built-in `open()` function and read the full contents into a variable called `summary`.
#
# > 💡 Hint: `with open("your_summary.txt", "r", encoding="utf-8") as f:  ...`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task 4 — Set your name
#
# Create a variable called `name` and set it to your own first name. This will be used throughout the system prompt.

# %%
# YOUR CODE HERE
name =

# %% [markdown]
# ### Task 5 — Build the system prompt
#
# Build a string called `system_prompt` using an f-string. It must:
#
# - Tell the model it is acting as `{name}`
# - Explain it is answering questions on `{name}`'s personal website
# - State its job is to represent `{name}` professionally to potential clients or employers
# - Mention it has access to a summary and a LinkedIn profile to draw from
# - Instruct it to say "I don't know" if it cannot answer
#
# Then append the `summary` and `linkedin` content to `system_prompt`, clearly labelled with `## Summary:` and `## LinkedIn Profile:` headers.
#
# Print the first 500 characters to verify it looks right.

# %%
# YOUR CODE HERE — build the base system prompt
system_prompt = f""

# YOUR CODE HERE — append summary and linkedin sections


# Verify
print(system_prompt[:500])

# %% [markdown]
# ### Task 6 — Write the chat function
#
# Write a function called `chat(message, history)` that:
#
# 1. Builds a `messages` list starting with the system prompt
# 2. Appends the conversation `history` (passed in by Gradio)
# 3. Appends the new user `message`
# 4. Calls `gpt-4o-mini` and returns the response text

# %%
def chat(message, history):
    # YOUR CODE HERE
    pass

# %% [markdown]
# ### Task 7 — Launch the Gradio chatbot
#
# Use `gr.ChatInterface` to launch your chatbot. Pass your `chat` function, set `type="messages"`, and give it a meaningful title — something like `"Chat with [Your Name]"`. Call `.launch()` to start it.
#
# > 💡 Hint: `gr.ChatInterface(fn=chat, type="messages", title="...").launch()`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task 8 — Test your chatbot
#
# Once the Gradio interface is running, test it with these questions and note what it says:
#
# 1. *"What is your professional background?"*
# 2. *"What skills do you have?"*
# 3. *"What are you looking for in your next role?"*
# 4. *"What was your most challenging project?"*
#
# **Reflection — answer here after testing:**
#
# 1. Did the chatbot stay in character as you?
# 2. Was there anything it got wrong or made up?
# 3. How would you improve `your_summary.txt` to fix this?

# %% [markdown]
# *Write your reflection answers here...*

# %% [markdown]
# ---
#
# ---
#
# # ✅ SOLUTION — scroll down only after attempting!
#
# ---
#
# ---

# %%
# SOLUTION — Task 1
from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

load_dotenv(override=True)
openai = OpenAI()

# %%
# SOLUTION — Task 2
reader = PdfReader("raz/ajaz.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

print(linkedin)

# %%
# SOLUTION — Task 3
with open("raz/razsystems.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
# SOLUTION — Task 4
name = "Aiza"   # replace with your own first name

# %%
# SOLUTION — Task 5
system_prompt = (
    f"You are acting as {name}. You are answering questions on {name}'s personal website, "
    f"particularly questions related to {name}'s career, background, skills and experience. "
    f"Your responsibility is to represent {name} for interactions on the website as faithfully as possible. "
    f"You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. "
    f"Be professional and engaging, as if talking to a potential client or future employer. "
    f"If you don't know the answer, say so."
)

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

print(system_prompt[:500])

# %%
# SOLUTION — Task 6
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}]
    messages += history
    messages += [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
# SOLUTION — Task 7
gr.ChatInterface(
    fn=chat,
    title=f"Chat with {name}"
).launch()

# %%
# SOLUTION — Task 8 reflection guide

# The chatbot should stay in character because the system prompt instructs it to.
# Common issues and fixes:
#
# Problem: It invents details not in your PDF
# Fix: Improve your_summary.txt with more concrete facts (projects, tools, years)
#
# Problem: It sounds too generic
# Fix: Add specific achievements, technologies, and goals to your_summary.txt
#
# Problem: It doesn't mention recent roles
# Fix: Check that print(linkedin) above shows the text correctly — some PDF exports
#      can produce garbled text if the file uses non-standard fonts
