# %% [markdown]
# <h1>RAZ Systems </h1>

# %%
import os
import json
from dotenv import load_dotenv
from supabase import create_client
from openai import OpenAI

# %%
load_dotenv(override=True)
# Out:
# True

# %%
openai_api_key = os.getenv('OPENAI_API_KEY')
supabase_api_key = os.getenv('SUBABASE_API_KEY')

# %%
# Supabase setup
url = "https://ssrxdvbnjfruzikvages.supabase.co"

supabase = create_client(url, supabase_api_key)

# OpenAI setup
client = OpenAI(api_key=openai_api_key)
# Out:
# APIResponse(data=[{'id': 2, 'content': 'RAZ System is developing AI enabled software for healthcase ', 'embedding': '[-0.021240234,0.006198883,-0.00025963783,0.057006836,0.008735657,-0.043426514,-0.022781372,0.042755127,0.0154953,-0.026031494,0.00579834,-0.087524414,-0.00054740906,-0.04006958,0.01852417,-0.019210815,0.0335083,-0.017715454,-0.051727295,0.013572693,-0.011352539,0.010871887,0.07220459,-0.047973633,0.0050086975,-0.047302246,-0.005077362,-0.02279663,0.024871826,-0.0067253113,0.022476196,-0.028274536,0.007358551,-0.0119018555,-0.0065193176,-0.014854431,-0.04425049,0.0026016235,-0.0016727448,0.08166504,-0.030349731,0.013168335,-0.0034446716,0.034057617,-0.009635925,0.0037231445,0.015945435,-0.047729492,0.035217285,0.012062073,-0.074157715,0.011177063,-0.054107666,0.009933472,-0.0057678223,0.032348633,-0.00071907043,0.072631836,0.0041503906,0.028274536,0.046905518,-0.017333984,0.0064353943,0.015136719,-0.053894043,-0.03945923,0.0027599335,0.0057029724,-0.013130188,-0.0095825195,0.0047569275,-0.010902405,0.016418457,0.024047852,0.002960205,-0.03050232,0.0043296814,0.052764893,0.026428223,0.03149414,-0.006374359,-0.011161804,0.009475708,-0.03048706,-0.009056091,-0.031921387,-0.05480957,-0.030273438,-0.07891846,-0.036743164,-0.003829956,0.047698975,-0.021697998,-0.009063721,0.017501831,0.005420685,-0.04168701,0.023925781,0.050842285,0.027435303,0.023712158,-0.050323486,-0.009902954,0.004043579,0.02961731,-0.012413025,0.011749268,-0.018997192,0.00023007393,0.014717102,-0.025146484,-0.0385437,-0.020370483,-0.008224487,-0.0059280396,-0.015136719,0.006160736,-0.051727295,0.0045814514,-0.0013847351,0.00793457,0.01889038,0.00012564659,-0.018707275,-0.03286743,-0.02420044,-0.019821167,-0.033416748,-0.040771484,0.006526947,-0.038360596,0.008850098,0.04220581,-0.01133728,-0.003660202,-0.03302002,0.01309967,-0.010528564,-0.011123657,-0.016616821,0.009353638,-0.011665344,-0.002204895,-0.0020866394,-0.06665039,-0.00047826767,-0.023239136,-0.061950684,-0.008140564,0.0046539307,-0.042022705,0.01322937,0.0020313263,0.01889038,-0.006465912,-0.01637268,0.02319336,0.02709961,-0.043182373,-0.020202637,-0.015113831,0.009231567,0.008102417,-0.012756348,0.026611328,0.01676941,0.010978699,-0.015289307,-0.048858643,0.013755798,-0.028182983,-0.0033226013,-0.06439209,-0.010131836,-0.019973755,0.004760742,0.071899414,-0.03717041,-0.029052734,-0.030944824,-0.020050049,-0.008766174,-0.029769897,0.04248047,-0.0034389496,0.0019779205,0.01789856,0.008308411,-0.00074863434,0.0001487732,0.016174316,0.028457642,-0.0095825195,0.0063285828,0.06555176,-0.021713257,-0.011497498,0.0046310425,-0.0053367615,-0.02671814,-0.014419556,-0.05493164,0.040893555,-0.014793396,0.0289917,0.03366089,0.0002169609,0.028182983,-0.035461426,-0.0023155212,0.017913818,0.022415161,0.05001831,0.02407837,-0.041900635,-0.018966675,0.029937744,0.025238037,0.036071777,0.031066895,-0.0051193237,0.012557983,0.045043945,-0.014602661,-0.018707275,-0.0040664673,0.009025574,-0.032440186,0.049591064,-0.029373169,0.027664185,0.062927246,-0.0073051453,0.008628845,0.006248474,-0.0043182373,-0.0056915283,-0.038604736,0.033233643,-0.050811768,0.0042800903,0.025756836,-0.0050239563,-0.0047798157,0.033233643,-0.0021877289,0.015563965,-0.0234375,0.025177002,-0.021881104,0.02748108,-0.001698494,0.029891968,-0.0055236816,-0.0073890686,0.03265381,-0.012138367,0.008338928,0.0042533875,-0.013061523,-0.033203125,-0.030639648,-0.026535034,-0.040924072,0.052703857,-0.017456055,0.017318726,0.018798828,-0.046813965,0.010566711,0.010543823,0.0085372925,0.04095459,-0.022598267,-0.029968262,0.0262146,0.02017212,-0.022018433,-0.052612305,0.02709961,-0.02180481,-0.013305664,0.008987427,-0.01977539,0.016860962,-0.009918213,-0.013252258,-0.029891968,-0.030715942,-0.005039215,0.009857178,-0.03942871,-0.019454956,-0.007888794,0.0033359528,-0.00819397,0.026168823,0.0017623901,0.025375366,0.055267334,0.075805664,-0.0056495667,0.025314331,-0.02796936,-0.039367676,0.042663574,-0.012710571,-0.03945923,0.026184082,0.0073013 ...

# %%
# Create an embedding
text = "Artificial intelligence for healthcare"
embedding = client.embeddings.create(
    model="text-embedding-3-small",
    input=text
).data[0].embedding

# Insert into Supabase
supabase.table("documents").insert({
    "content": text,
    "embedding": embedding
}).execute()

# %%
# Create an embedding
text = "RAZ System is developing AI enabled software for healthcase "
embedding = client.embeddings.create(
    model="text-embedding-3-small",
    input=text
).data[0].embedding

# Insert into Supabase
supabase.table("documents").insert({
    "content": text,
    "embedding": embedding
}).execute()

# %%
query = "AI in hospitals"
query_embedding = client.embeddings.create(
    model="text-embedding-3-small",
    input=query
).data[0].embedding

response = supabase.rpc("match_documents", {
    "query_embedding": query_embedding,
    "match_threshold": 0.6,
    "match_count": 5
}).execute()

print(response.data)
# Out:
# [{'id': 1, 'content': 'Artificial intelligence for healthcare', 'similarity': 0.696360841788145}]

# %%
query = "which company is working on software"
query_embedding = client.embeddings.create(
    model="text-embedding-3-small",
    input=query
).data[0].embedding

response = supabase.rpc("match_documents", {
    "query_embedding": query_embedding,
    "match_threshold": 0.4,
    "match_count": 5
}).execute()

print(response.data)
# Out:
# [{'id': 2, 'content': 'RAZ System is developing AI enabled software for healthcase ', 'similarity': 0.4278970330237}]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
