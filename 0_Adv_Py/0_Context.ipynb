# %%
### Without context management (risky)
f = open("data/data.txt", "r")
data = f.read()
# if an error happens here, f.close() never runs — file stays open
print(data)
f.close()
# Out:
# Hello, Imran Latif How are you doing ?

# %%
### With context management (safe)
# Reading a file
with open("data/data.txt", "r") as f:
    data = f.read()
    print(data)
    f.close

With open("data/data.txt", "r") as f1:
    data1 = f1.read()
    print(data)
# file is automatically closed here — even if an error occurred inside
# Out:
# Hello, Imran Latif How are you doing ?

# %%
with open("data/output.txt", "w") as f:
    f.write("Hello World")
# file is saved and closed automatically

# %%
# Appending to a file
with open("data/output.txt", "a") as f:
    f.write("\nNew line This is writing to file in append mode")
# file is closed automatically

# %%
### With context management (safe)
# Reading a file
with open("data/output.txt", "r") as f:
    data = f.read()
    print(data)
# file is automatically closed here — even if an error occurred inside
# Out:
# Hello World
# New line added
# New line This is writing to file in append mode
